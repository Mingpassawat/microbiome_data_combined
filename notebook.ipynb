# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y = pd.read_csv("data/combined_microbiome/metadata.csv", index_col=0).drop(columns='sample_key.1')
# Out:
# /var/folders/h3/pwlyvdxs71v5yn4z60q6qlv40000gn/T/ipykernel_56605/3756819998.py:1: DtypeWarning: Columns (9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   y = pd.read_csv("data/combined_microbiome/metadata.csv", index_col=0).drop(columns='sample_key.1')

# %%
X = pd.read_csv("/Users/ming/Documents/GitHub/Microbiome_transformer/data/combined_microbiome/relative_abundance_species_proportions_wide.csv", index_col=0)

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (33442, 2817)
# y shape: (33442, 15)

# %%
y.head()
# Out:
#                   source original_sample_key      sample_id       study_id  \
# sample_key
# cmd:MV_FEI1_t1Q14    cmd       MV_FEI1_t1Q14  MV_FEI1_t1Q14  AsnicarF_2017
# cmd:MV_FEI2_t1Q14    cmd       MV_FEI2_t1Q14  MV_FEI2_t1Q14  AsnicarF_2017
# cmd:MV_FEI3_t1Q14    cmd       MV_FEI3_t1Q14  MV_FEI3_t1Q14  AsnicarF_2017
# cmd:MV_FEI4_t1Q14    cmd       MV_FEI4_t1Q14  MV_FEI4_t1Q14  AsnicarF_2017
# cmd:MV_FEI4_t2Q15    cmd       MV_FEI4_t2Q15  MV_FEI4_t2Q15  AsnicarF_2017
#
#                      label  is_healthy  age  gender country body_site  \
# sample_key
# cmd:MV_FEI1_t1Q14  Healthy        True  0.0  female     ITA     stool
# cmd:MV_FEI2_t1Q14  Healthy        True  0.0    male     ITA     stool
# cmd:MV_FEI3_t1Q14  Healthy        True  0.0    male     ITA     stool
# cmd:MV_FEI4_t1Q14  Healthy        True  1.0    male     ITA     stool
# cmd:MV_FEI4_t2Q15  Healthy        True  1.0    male     ITA     stool
#
#                   age_years  sex continent           group_id split
# ...

# %%
X.head()
# Out:
#                    s__Abelson_murine_leukemia_virus  s__Abiotrophia_defectiva  \
# sample_key
# cmd:MV_FEI1_t1Q14                               0.0                       0.0
# cmd:MV_FEI2_t1Q14                               0.0                       0.0
# cmd:MV_FEI3_t1Q14                               0.0                       0.0
# cmd:MV_FEI4_t1Q14                               0.0                       0.0
# cmd:MV_FEI4_t2Q15                               0.0                       0.0
#
#                    s__Abiotrophia_sp_HMSC24B09  s__Absiella_dolichum  \
# sample_key
# cmd:MV_FEI1_t1Q14                          0.0                   0.0
# cmd:MV_FEI2_t1Q14                          0.0                   0.0
# cmd:MV_FEI3_t1Q14                          0.0                   0.0
# cmd:MV_FEI4_t1Q14                          0.0                   0.0
# cmd:MV_FEI4_t2Q15                          0.0                   0.0
#
# ...
